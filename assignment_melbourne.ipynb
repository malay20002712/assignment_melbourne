# %%
from numpy import *
from pandas import *
from matplotlib.pyplot import *
from seaborn import *

# %%
melbourne_data = read_csv ('C:\\Users\\DELL\\Desktop\\melbournedata\\melb_data.csv')
melbourne_data.head ()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-12-2016       2.5      3067  ...         1  1.0       202           NaN
# 1  04-02-2016       2.5      3067  ...         1  0.0       156          79.0
# 2  04-03-2017       2.5      3067  ...         2  0.0       134         150.0
# 3  04-03-2017       2.5      3067  ...         2  1.0        94           NaN
# 4  04-06-2016       2.5      3067  ...         1  2.0       120         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
# finding out the missing values
melbourne_data.isnull ().sum ().sort_values (ascending = True)
# Out:
# Suburb            0
# Longtitude        0
# Lattitude         0
# CouncilArea       0
# YearBuilt         0
# BuildingArea      0
# Landsize          0
# Bathroom          0
# Regionname        0
# Bedroom2          0
# Distance          0
# Date              0
# SellerG           0
# Method            0
# Price             0
# Type              0
# Rooms             0
# Address           0
# Postcode          0
# Propertycount     0
# Car              62
# dtype: int64

# %%
m_d_col = melbourne_data.isnull().any ()

# %%
m_d_col.index[m_d.values]
# Out:
# Index(['Car'], dtype='object')

# %%
m_d_rows = melbourne_data.isnull().any (axis = 1)

# %%
m_d_rows
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13575    False
# 13576    False
# 13577    False
# 13578    False
# 13579    False
# Length: 13580, dtype: bool

# %%
MD = m_d_rows.index [m_d_rows.values]

# %%
melbourne_data.iloc[MD, :]
# Out:
#                 Suburb            Address  Rooms Type    Price Method  \
# 12221       Ascot Vale     132 The Parade      3    h   985000      S
# 12247   Brunswick East        18 Ethel St      2    h  1023000      S
# 12259     Clifton Hill      34 Fenwick St      3    h  1436000      S
# 12320    Glen Waverley      19 Diamond Av      3    h  1370000      S
# 12362          Newport  11 Collingwood Rd      4    h  1180000     PI
# ...                ...                ...    ...  ...      ...    ...
# 13496     Moonee Ponds     46 Eglinton St      4    h  1525000      S
# 13508  North Melbourne       9 Erskine St      2    h  1080000      S
# 13522   Port Melbourne      201 Stokes St      2    h  1515000     SP
# 13524          Prahran   17 Packington Pl      2    h  1365000      S
# 13550   Sunshine North     5 Berkshire Rd      3    h   595000     SP
#
#          SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
melbourne_data.isnull ().all ().sum () #columns having all missing values
# Out:
# 0

# %%
# rows having all null values
melbourne_data.isnull ().all (axis = 1).sum ()
# Out:
# 0

# %%
address = melbourne_df ['Address'].tolist ()

# %%
round (melbourne_data.isnull ().sum ().sort_values (ascending = False) / len (melbourne_data) * 100, 2)
# Out:
# Car              0.46
# Suburb           0.00
# Bathroom         0.00
# Regionname       0.00
# Longtitude       0.00
# Lattitude        0.00
# CouncilArea      0.00
# YearBuilt        0.00
# BuildingArea     0.00
# Landsize         0.00
# Bedroom2         0.00
# Address          0.00
# Postcode         0.00
# Distance         0.00
# Date             0.00
# SellerG          0.00
# Method           0.00
# Price            0.00
# Type             0.00
# Rooms            0.00
# Propertycount    0.00
# dtype: float64

# %%
max_null_values = melbourne_data.isnull ().sum ().sort_values (ascending = False).head (1).index.values

# %%
max_null_values
# Out:
# array(['Car'], dtype=object)

# %%
melbourne_data.drop (max_null_values, axis = 'columns')
# Out:
#               Suburb           Address  Rooms Type    Price Method   SellerG  \
# 0         Abbotsford      85 Turner St      2    h  1480000      S    Biggin
# 1         Abbotsford   25 Bloomburg St      2    h  1035000      S    Biggin
# 2         Abbotsford      5 Charles St      3    h  1465000     SP    Biggin
# 3         Abbotsford  40 Federation La      3    h   850000     PI    Biggin
# 4         Abbotsford       55a Park St      4    h  1600000     VB    Nelson
# ...              ...               ...    ...  ...      ...    ...       ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000      S     Barry
# 13576   Williamstown     77 Merrett Dr      3    h  1031000     SP  Williams
# 13577   Williamstown       83 Power St      3    h  1170000      S     Raine
# 13578   Williamstown      96 Verdon St      4    h  2500000     PI   Sweeney
# 13579     Yarraville        6 Agnes St      4    h  1285000     SP   Village
#
# ...

# %%
melbourne_data = melbourne_data.isnull ().sum (axis = 1) <= 3
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 13575    True
# 13576    True
# 13577    True
# 13578    True
# 13579    True
# Length: 13580, dtype: bool

# %%
round (melbourne_data.isnull ().sum ().sort_values (ascending = False) / len (melbourne_data) * 100, 2)
# Out:
# Car              0.46
# Suburb           0.00
# Bathroom         0.00
# Regionname       0.00
# Longtitude       0.00
# Lattitude        0.00
# CouncilArea      0.00
# YearBuilt        0.00
# BuildingArea     0.00
# Landsize         0.00
# Bedroom2         0.00
# Address          0.00
# Postcode         0.00
# Distance         0.00
# Date             0.00
# SellerG          0.00
# Method           0.00
# Price            0.00
# Type             0.00
# Rooms            0.00
# Propertycount    0.00
# dtype: float64

# %%
melbourne_data.loc [:,['Lattitude', 'Longtitude']].describe ()
# Out:
#           Lattitude    Longtitude
# count  13580.000000  13580.000000
# mean     -37.809203    144.995216
# std        0.079260      0.103916
# min      -38.182550    144.431810
# 25%      -37.856822    144.929600
# 50%      -37.802355    145.000100
# 75%      -37.756400    145.058305
# max      -37.408530    145.526350

# %%
lattitude_mean = melbourne_data ['Lattitude'].mean ()

# %%
longitude_mean = melbourne_data ['Longtitude'].mean ()

# %%
lattitude_mean
# Out:
# -37.809202733431505

# %%
longitude_mean
# Out:
# 144.99521618777578

# %%
melbourne_data.loc [:, 'Lattitude'].fillna (lattitude_mean, inplace=True)

# %%
melbourne_data.loc [:, 'Longitude'].fillna (lattitude_mean, inplace=True)
